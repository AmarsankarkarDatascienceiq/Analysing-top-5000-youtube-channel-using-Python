# %% [markdown]
# <a href="https://colab.research.google.com/github/AmarsankarkarDatascienceiq/Analysing-top-5000-youtube-channel-using-Python/blob/main/Top_5000_youtube_channel_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Datasets and Projects/Top 5000 youtube channels/top-5000-youtube-channels.csv')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
#Display all rown except the last 5 rows of the dataset
data.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
#display all methods except the first five methods
data.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %%
#find the shape of our dataset
data.shape
# Out:
# (5000, 6)

# %%
print('no of rows',data.shape[0])
print('no of columns',data.shape[1])
# Out:
# no of rows 5000
# no of columns 6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
#get all the stats of the data
data.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %%
#data cleaning

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
import numpy as np

# %%
data=data.replace('--',np.nan,regex=True)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
#check null values in the dataset

# %%
data.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
percentage_missing = data.isnull().sum()*100/len(data)

# %%
percentage_missing
# Out:
# Rank             0.00
# Grade            0.00
# Channel name     0.00
# Video Uploads    0.12
# Subscribers      7.74
# Video views      0.00
# dtype: float64

# %%
sns.heatmap(data.isnull())

# %%
data.dropna(axis=0,inplace=True)

# %%
sns.heatmap(data.isnull())

# %%
#data cleaning rank column

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
#we need to change rank columns into int

# %%
data['Rank']= data['Rank'].str['0:-2']

# %%
data.head()
# Out:
#    Rank Grade                Channel name Video Uploads Subscribers  \
# 0   NaN  A++                       Zee TV         82757    18752951
# 1   NaN  A++                     T-Series         12661    61196302
# 2   NaN  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3   NaN  A++                    SET India         27323    31180559
# 4   NaN  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data['Rank'].str.replace(',','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-bae4954d26de> in <module>
# ----> 1 data['Rank'].str.replace(',','')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
data.dtypes
# Out:
# Rank             float64
# Grade             object
# Channel name      object
# Video Uploads     object
# Subscribers       object
# Video views        int64
# dtype: object

# %%
data['Video Uploads']= data['Video Uploads'].astypes('int')
data['Subscribers']= data['Subscribers'].astypes('int')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-89239159a6d8> in <module>
# ----> 1 data['Video Uploads']= data['Video Uploads'].astypes('int')
#       2 data['Subscribers']= data['Subscribers'].astypes('int')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'astypes'

# %%
data.dtypes
# Out:
# Rank             float64
# Grade             object
# Channel name      object
# Video Uploads     object
# Subscribers       object
# Video views        int64
# dtype: object

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade']=data['Grade'].map({'A++ ':5,'A+ ':4,'A ':3,'A- ':2,'B+ ':1})

# %%
data.head()
# Out:
#    Rank  Grade                Channel name Video Uploads Subscribers  \
# 0   NaN      5                      Zee TV         82757    18752951
# 1   NaN      5                    T-Series         12661    61196302
# 2   NaN      5  Cocomelon - Nursery Rhymes           373    19238251
# 3   NaN      5                   SET India         27323    31180559
# 4   NaN      5                         WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
#find the avg views of each channels

# %%
data['Avg_Views'] = data['Video views']/data['Video Uploads']

# %%
data.sort_values(by='Video Uploads',ascending=False.head())

# %%
#Find correlation matrix

# %%
data.corr()
# Out:
#              Rank     Grade  Video views
# Rank          NaN       NaN          NaN
# Grade         NaN  1.000000     0.477423
# Video views   NaN  0.477423     1.000000

# %%
#Which grade has maximum no of video uploads

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
sns.barplot(x='Grade', y='Video Uploads'data=data)

# %%
#Which grade has highest avg views
